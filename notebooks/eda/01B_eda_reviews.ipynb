# %% [markdown]
# # 1. Importación
#
# Carga de las librerías necesarias y del dataset original en crudo.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/yagocoll/Documents/Master/Airbnb/data/raw/reviews.csv")
df.head()
# Out:
#    listing_id        date
# 0       18674  2013-05-27
# 1       18674  2014-03-02
# 2       18674  2015-08-04
# 3       18674  2016-06-20
# 4       18674  2018-06-18

# %% [markdown]
# ## 2. Básico
#
# Primer vistazo a la estructura del dataset: dimensiones, tipos de datos y estadísticos descriptivos generales.

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (1033523, 2)
# listing_id     int64
# date          object
# dtype: object

# %%
df.describe(include="all")
# Out:
#           listing_id        date
# count   1.033523e+06     1033523
# unique           NaN        5217
# top              NaN  2026-06-07
# freq             NaN        1167
# mean    1.984766e+17         NaN
# std     4.196039e+17         NaN
# min     1.867400e+04         NaN
# 25%     3.966264e+06         NaN
# 50%     2.160051e+07         NaN
# 75%     5.055624e+07         NaN
# max     1.711531e+18         NaN

# %% [markdown]
# ## 3. Corrección de tipos
#
# Convertir `date` (texto) a `datetime` para poder trabajar con fechas.

# %% [markdown]
# ## 4. Nulos
#
# Comprobar si hay valores nulos en `listing_id` o `date`.

# %% [markdown]
# ## 5. Duplicados
#
# Filas con el mismo `listing_id` y `date`. Aviso: el dataset no tiene id de review ni hora exacta, así que dos reviews reales distintas el mismo día son indistinguibles de una fila duplicada — hay que decidir con cuidado si se tratan como error o como reviews múltiples legítimas.

# %% [markdown]
# ## 6. Análisis temporal
#
# Evolución del número de reviews a lo largo del tiempo (por año/mes) y estacionalidad.

# %% [markdown]
# ## 7. Reviews por listing
#
# Distribución del número de reviews por anuncio; cruce con `listings_clean.csv` (sección 13 de `01A_eda_listings.ipynb`) para contrastar con `number_of_reviews`.

# %% [markdown]
# ## 8. Conclusiones
#
# Resumen de los principales hallazgos.

# %% [markdown]
# ## 9. Exportar dataset
#
# Guardar el resultado (p. ej. agregados por listing) en `data/processed/` para su uso posterior.
