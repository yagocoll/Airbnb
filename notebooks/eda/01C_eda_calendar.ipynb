# %% [markdown]
# # 1. Importación
#
# Carga de las librerías necesarias y del dataset original en crudo.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/yagocoll/Documents/Master/Airbnb/data/raw/calendar.csv.gz")
df.head()
# Out:
#    listing_id        date available  minimum_nights  maximum_nights
# 0       18674  2026-06-25         f               1             999
# 1       18674  2026-06-26         f               2             999
# 2       18674  2026-06-27         f               2             999
# 3       18674  2026-06-28         t               1             999
# 4       18674  2026-06-29         f               3             999

# %% [markdown]
# ## 2. Básico
#
# Primer vistazo a la estructura del dataset: dimensiones, tipos de datos y estadísticos descriptivos generales.

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (5623190, 5)
# listing_id         int64
# date              object
# available         object
# minimum_nights     int64
# maximum_nights     int64
# dtype: object

# %%
df.describe(include="all")
# Out:
#           listing_id        date available  minimum_nights  maximum_nights
# count   5.623190e+06     5623190   5623190    5.623190e+06    5.623190e+06
# unique           NaN         374         2             NaN             NaN
# top              NaN  2026-12-29         t             NaN             NaN
# freq             NaN       15406   3281038             NaN             NaN
# mean    7.143752e+17         NaN       NaN    1.735840e+01    5.341579e+02
# std     6.567864e+17         NaN       NaN    4.089260e+01    4.242429e+02
# min     1.867400e+04         NaN       NaN    1.000000e+00    1.000000e+00
# 25%     3.253724e+07         NaN       NaN    2.000000e+00    1.800000e+02
# 50%     8.102725e+17         NaN       NaN    4.000000e+00    3.650000e+02
# 75%     1.353473e+18         NaN       NaN    3.100000e+01    1.125000e+03
# max     1.714532e+18         NaN       NaN    1.000000e+03    1.125000e+03

# %% [markdown]
# ## 3. Corrección de tipos
#
# Convertir `date` a `datetime` y `available` (texto `t`/`f`) a booleano.

# %% [markdown]
# ## 4. Nulos
#
# Comprobar si hay valores nulos en alguna columna.

# %% [markdown]
# ## 5. Duplicados
#
# Comprobar filas con el mismo `listing_id` y `date` (debería haber exactamente una fila por anuncio y día).

# %% [markdown]
# ## 6. Análisis temporal
#
# Evolución de la disponibilidad (`available`) a lo largo del año: ¿hay estacionalidad, meses con más ocupación?

# %% [markdown]
# ## 7. Disponibilidad por listing
#
# Nº de días disponibles por anuncio en el año siguiente; cruce con `listings_clean.csv` (sección 13 de `01A_eda_listings.ipynb`) para contrastar con `availability_365`. También comprobar si `minimum_nights`/`maximum_nights` varían por fecha para un mismo anuncio.

# %% [markdown]
# ## 8. Conclusiones
#
# Resumen de los principales hallazgos.

# %% [markdown]
# ## 9. Exportar dataset
#
# Guardar el resultado (p. ej. agregados por listing) en `data/processed/` para su uso posterior.
