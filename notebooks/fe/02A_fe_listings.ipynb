# %% [markdown]
# # Inicio

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/Users/yagocoll/Documents/Master/Airbnb/data/raw/listings.csv")
df.head()
# Out:
#       id                                             name   host_id  \
# 0  18674  Huge flat for 8 people close to Sagrada Familia   71615.0
# 1  23197   CCIB Forum· Large Balcony · 5 min walk to CCIB   90417.0
# 2  34981             VIDRE HOME PLAZA REAL on LAS RAMBLAS   73163.0
# 3  36763                            In front of the beach  158596.0
# 4  40983  Architect's Loft near Gaudí & Passeig de Gràcia  177617.0
#
#    host_profile_id                         host_name neighbourhood_group  \
# 0     1.462508e+18  Maria Y Mireia Barcelona4Seasons            Eixample
# 1     1.462509e+18                            Marnie          Sant Martí
# 2     1.462508e+18                            Andres        Ciutat Vella
# 3     1.462511e+18                             Ester        Ciutat Vella
# 4     1.462512e+18                           Joaquin            Eixample
#
#             neighbourhood   latitude  longitude        room_type  price  \
# ...

# %% [markdown]
# ## Transformaciones Númericas

# %% [markdown]
# ### Logaritmos

# %%
sns.histplot(data=df, x="price")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
df["price_log"] = np.log(df["price"])

sns.histplot(df, x="price_log", hue="room_type")
# Out:
# <Axes: xlabel='price_log', ylabel='Count'>

# %% [markdown]
# ### Ratios

# %%
df["price_per_min_night"] = df["price"] / df["minimum_nights"]
sns.histplot(df, x="price_per_min_night")
# Out:
# <Axes: xlabel='price_per_min_night', ylabel='Count'>

# %%
sns.boxplot(df, x="price_per_min_night")
# Out:
# <Axes: xlabel='price_per_min_night'>

# %% [markdown]
# ## Codificación de categóricas

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

encoder = OneHotEncoder(handle_ignore=False)

# oneHot para categoricas sin orden que sean pocas -> roomtypes

# %%
df["neighbourhood_price_mean"] = df.groupby("neighbourhood")["price"].transform("mean")
